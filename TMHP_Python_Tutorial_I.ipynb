# %% [markdown]
# <table style="float:center; border:none">
#    <tr style="border:none; background-color: #ffffff">
#        <td style="border:none">
#            <a href="http://www.accenture.com">
#            <img
#                src="./ACN_Logo/Acc_Operations_Lockup_BLK.png"
#                style="width:1000px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#        </td>
#    </tr>
# </table>

# %% [markdown]
# # **_TMHP Python Tutorial_**
# ### *February 2019*

# %% [markdown]
# # **_Introduction_**
#
# <table style="float:center; border:none">
#    <tr style="border:none; background-color: #ffffff">
#        <td style="border:none">
#            <img
#                src="./Introduction/Introduction.png"
#                style="width:500px"
#            >
#        </td>
#        <td style="border:none">
#        </td>
#    </tr>
# </table>
#
# ## One of the more frequent questions I hear is "How did you become a data scientist?"  The second most frequent question is "What is data science?"
#
# # **_My Data Science Path_**
# ### As with most data science paths, mine begins with learning Microsoft Excel.  Excel is a fabulous tool, but it's not without it's limitations.  From there, I learned VBA in order to automate daily reporting tasks, and grew my coding skills from there.  I dabbled in R for roughly a decade before I knew how to effectively use it, and lately I've been using Python as my main coding language.

# %% [markdown]
# # **_Today's Session_**
# ### - **Introduction to Jupyter Notebooks:**  First, we'll get set up with your very own Jupyter Notebook so you'll be able to code along.
# ### - **Loading in a Data Set:**  Next, we'll learn how to load in basic data sets, including Excel files and .csv files.
# ### - **Creating a Pivot Table:**  Then, we'll explore a high-level relationship among the data using a pivot table.
# ### - **Exploring Data Visualization:**  After that, we'll make a few quick charts to show off our new skils.
# ### - **Automating Reports:**  Finally, we'll see a real example of how we can automatically e-mail reports to a distribution list.

# %% [markdown]
# ___

# %% [markdown]
# ## **_Introduction to Jupyter Notebooks_**

# %% [markdown]
# ### The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.

# %% [markdown]
# <table style="float:center; border:none">
#    <tr style="border:none; background-color: #ffffff">
#        <td style="border:none">
#            <img
#                src="./Introduction/Jupyter_Logo.png"
#                style="width:200px"
#            >
#        </td>
#        <td style="border:none">
#        </td>
#    </tr>
# </table>

# %% [markdown]
# ### **_Before we begin our tutorial, we'll need to install a few underlying Python modules._**
#
# - Python has a way to put definitions in a file and use them in a script or in an interactive instance of the interpreter. Such a file is called a module; definitions from a module can be imported into other modules or into the main module (the collection of variables that you have access to in a script executed at the top level and in calculator mode).
#
# - A module is a file containing Python definitions and statements.

# %%
# Install a pip package in the current Jupyter kernel
import sys

# Install the Pandas Module
# !{sys.executable} -m pip install pandas

# Install the NumPy Module
# !{sys.executable} -m pip install numpy

# Install the Seaborn Module
# !{sys.executable} -m pip install seaborn

# Install the Seaborn Module
# !{sys.executable} -m pip install xlrd

# %% [markdown]
# ### **_Next, we'll need to import the Python modules.  For our tutorial, we'll keep the number of packages we import to a minimum_**
#
# - **Pandas:**  The Python Data Analysis Library (*pandas*) is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language
# - **NumPy:**  NumPy is the fundamental package for scientific computing with Python
# - **Seaborn:**  Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
# - **MatPlotLib:**  Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms

# %%
# Import the Necessary Packages
import pandas as pd
import numpy as np
import seaborn as sns
import xlrd

# %% [markdown]
# ___

# %% [markdown]
# ## **_Loading and Cleaning a Data Set_**

# %% [markdown]
# #### Now that we have completed our initial set up completed, we can start to analyze some data sets!  As with most data sets, our initial practice will begin with the data in an Excel format.  For this tutorial, let's define a business problem that we'd like to solve, and then take the necessary steps to produce a concise visual.

# %% [markdown]
# ### **_Business Problem:_**  Given a data set of monthly CHIP data, we want to visualize the monthly trends for the following columns (features):
# #### - Chip Caseloads
# #### - New Enrollments
# #### - Renewals
# #### - Disenrollments

# %% [markdown]
# #### First, we'll need to acquire the underlying data set.  For our tutorial, I've downloaded the **CHIP Monthly Enrollment Detail** data from the following [Healthcare Statistics | Texas Health and Human Services](https://hhs.texas.gov/about-hhs/records-statistics/data-statistics/healthcare-statistics) web page.
#
# #### We'll use the Pandas module to read the data from an Excel file as our first step.

# %%
# Using Pandas, Read in the Data Source and Name it "CHIP_Data"
CHIP_Data = pd.read_excel("chip-enrollment-detail-oct-2018.xlsx")

# Preview the Data Set and Compare to the Excel Format
CHIP_Data.head(10)
# Out:
#   Children's Health Insurance Program     Unnamed: 1      Unnamed: 2  \
# 0                               Month  CHIP Caseload  New Enrollment
# 1                 2018-10-01 00:00:00         384336           27548
# 2                 2018-09-01 00:00:00         390250           28724
# 3                 2018-08-01 00:00:00         392085           30811
# 4                 2018-07-01 00:00:00         393065           26214
# 5                 2018-06-01 00:00:00         397606           28397
# 6                 2018-05-01 00:00:00         408449           33296
# 7                 2018-04-01 00:00:00         412736           30459
# 8                 2018-03-01 00:00:00         420340           36003
# 9                 2018-02-01 00:00:00         419772           31448
#
#   Unnamed: 3     Unnamed: 4
# 0   Renewals  Disenrollment
# 1       9511          33315
# 2      12544          30437
# 3       8822          31635
# 4       9329          30646
# 5      14196          39027
# ...

# %% [markdown]
# #### Looking at our imported data, we notice that our headers seem to be off.  So, in order to properly format our data set, we'll tell the Pandas read_excel pacakge to skip the first row using the following line of code:

# %%
# Using Pandas, Read in the Data Source and Name it "CHIP_Data"
CHIP_Data = pd.read_excel("chip-enrollment-detail-oct-2018.xlsx", header = 1)

# %%
# Preview the Data Set and Compare to the Excel Format
CHIP_Data.head(10)
# Out:
#                  Month  CHIP Caseload  New Enrollment  Renewals  Disenrollment
# 0  2018-10-01 00:00:00       384336.0         27548.0    9511.0        33315.0
# 1  2018-09-01 00:00:00       390250.0         28724.0   12544.0        30437.0
# 2  2018-08-01 00:00:00       392085.0         30811.0    8822.0        31635.0
# 3  2018-07-01 00:00:00       393065.0         26214.0    9329.0        30646.0
# 4  2018-06-01 00:00:00       397606.0         28397.0   14196.0        39027.0
# 5  2018-05-01 00:00:00       408449.0         33296.0   10872.0        37392.0
# 6  2018-04-01 00:00:00       412736.0         30459.0   11185.0        37988.0
# 7  2018-03-01 00:00:00       420340.0         36003.0   14132.0        35229.0
# 8  2018-02-01 00:00:00       419772.0         31448.0   10290.0        31623.0
# 9  2018-01-01 00:00:00       420154.0         26134.0    9766.0        28145.0

# %%
# Preview the Data Set and Compare to the Excel Format
CHIP_Data.tail(10)
# Out:
#                                                 Month  CHIP Caseload  \
# 57                                2014-01-01 00:00:00       567267.0
# 58                                2013-12-01 00:00:00       562826.0
# 59                                2013-11-01 00:00:00       581672.0
# 60                                2013-10-01 00:00:00       602457.0
# 61                                2013-09-01 00:00:00       607787.0
# 62                                                NaN            NaN
# 63                                              Notes            NaN
# 64  Highlighted monthly caseloads are incomplete a...            NaN
# 65                                   Source: PPS Data            NaN
# 66                                   HHSC Forecasting            NaN
#
#     New Enrollment  Renewals  Disenrollment
# 57         42350.0   18076.0        38026.0
# 58         26408.0   17114.0        44944.0
# 59         35889.0   27804.0        56678.0
# ...

# %% [markdown]
# #### Similarly, we have summary totals at the bottom of the file that we'll need to get rid of.  Again, we can modify our code to skip the summary rows at the bottom of the file.

# %%
# Using Pandas, Read in the Data Source and Name it "CHIP_Data"
CHIP_Data = pd.read_excel("chip-enrollment-detail-oct-2018.xlsx", header = 1, skipfooter = 5)

# %%
# Preview the Data Set and Compare to the Excel Format
CHIP_Data.head(10)
# Out:
#        Month  CHIP Caseload  New Enrollment  Renewals  Disenrollment
# 0 2018-10-01         384336           27548      9511          33315
# 1 2018-09-01         390250           28724     12544          30437
# 2 2018-08-01         392085           30811      8822          31635
# 3 2018-07-01         393065           26214      9329          30646
# 4 2018-06-01         397606           28397     14196          39027
# 5 2018-05-01         408449           33296     10872          37392
# 6 2018-04-01         412736           30459     11185          37988
# 7 2018-03-01         420340           36003     14132          35229
# 8 2018-02-01         419772           31448     10290          31623
# 9 2018-01-01         420154           26134      9766          28145

# %%
# Preview the Bottom of the Data Set and Compare to the Excel Format
CHIP_Data.tail(10)
# Out:
#         Month  CHIP Caseload  New Enrollment  Renewals  Disenrollment
# 52 2014-06-01         465587           21790      8238          41327
# 53 2014-05-01         485124           36291      8422          46354
# 54 2014-04-01         495187           28082     10447          62377
# 55 2014-03-01         529495           22421     13306          53887
# 56 2014-02-01         560961           35804     17881          42122
# 57 2014-01-01         567267           42350     18076          38026
# 58 2013-12-01         562826           26408     17114          44944
# 59 2013-11-01         581672           35889     27804          56678
# 60 2013-10-01         602457           28355     19680          33505
# 61 2013-09-01         607787           37226     23736          25102

# %% [markdown]
# #### Our variable *CHIP_Data* is now loaded with the data from the Excel sheet.  Let's take a quick look and gather some high-level insight into the data using built-in Python commands.

# %%
# Use the Info Function
CHIP_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 5 columns):
# Month             62 non-null datetime64[ns]
# CHIP Caseload     62 non-null int64
# New Enrollment    62 non-null int64
# Renewals          62 non-null int64
# Disenrollment     62 non-null int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 2.5 KB

# %%
# Describe the Data
CHIP_Data.describe()
# Out:
#        CHIP Caseload  New Enrollment      Renewals  Disenrollment
# count      62.000000       62.000000     62.000000      62.000000
# mean   404681.758065    29348.548387  10823.258065   32697.000000
# std     70757.920334     5505.845170   4074.288681    8880.961479
# min    324225.000000    13776.000000   5596.000000   19127.000000
# 25%    354460.500000    26229.500000   8425.000000   26310.500000
# 50%    391507.000000    29404.000000   9550.500000   30541.500000
# 75%    417573.000000    33125.750000  11606.750000   37307.500000
# max    607787.000000    42350.000000  27804.000000   62377.000000

# %%
# Look at the Entire Data Set
CHIP_Data
# Out:
#         Month  CHIP Caseload  New Enrollment  Renewals  Disenrollment
# 0  2018-10-01         384336           27548      9511          33315
# 1  2018-09-01         390250           28724     12544          30437
# 2  2018-08-01         392085           30811      8822          31635
# 3  2018-07-01         393065           26214      9329          30646
# 4  2018-06-01         397606           28397     14196          39027
# 5  2018-05-01         408449           33296     10872          37392
# 6  2018-04-01         412736           30459     11185          37988
# 7  2018-03-01         420340           36003     14132          35229
# 8  2018-02-01         419772           31448     10290          31623
# 9  2018-01-01         420154           26134      9766          28145
# 10 2017-12-01         422402           29702     18391          25956
# 11 2017-11-01         418794           37196     11760          26315
# ...

# %% [markdown]
# #### Great!  Our data set looks like it's clean and in good shape!  Let's do one more step in our exploratory data analysis to make sure it makes sense.  Let's compare the values among the *CHIP Caseload*, *New Enrollment*, *Renewals*, and *Disenrollment* columns using a box plot.  For this exercise, we'll create four separate plots, one for each column.

# %%
# Retrieve the Column Names for Reference
CHIP_Data.columns
# Out:
# Index(['Month', 'CHIP Caseload', 'New Enrollment', 'Renewals',
#        'Disenrollment'],
#       dtype='object')

# %% [markdown]
# ### **_CHIP Caseload Box Plot_**

# %%
BoxPlot_CHIP_Caseload = sns.boxplot(x = CHIP_Data['CHIP Caseload'])

# %% [markdown]
# ### **_New Enrollments Box Plot_**

# %%
BoxPlot_CHIP_New_Enrollments = sns.boxplot(x = CHIP_Data['New Enrollment'])

# %% [markdown]
# ### **_Renewals Box Plot_**

# %%
BoxPlot_CHIP_Renewals = sns.boxplot(x = CHIP_Data['Renewals'])

# %% [markdown]
# ### **_Disenrollments Box Plot_**

# %%
# Fill in the Below with the Necessary Variables for Disenrollments
BoxPlot_CHIP_Caseload = sns.boxplot(x = CHIP_Data['CHIP Caseload'])

# Hints:
# Change the Variable Name
# Change the Column Name

# %% [markdown]
# ___

# %% [markdown]
# ## **_Data Visualization_**

# %% [markdown]
# #### After analyzing our data and cleaning it, we feel confident that the underlying data set is accurate.  Going back to our business problem of Analyzing Monthly Trends for each of the columns, we can leverage the Python module Seaborn to quickly create charts.

# %% [markdown]
# ### **_Time Series Analysis (CHIP Caseloads)_**

# %%
# Time Series Analysis (Chip Caseloads)
CHIP_Data_Visual_Caseloads = sns.lineplot(x="Month", y="CHIP Caseload", data=CHIP_Data)

# %% [markdown]
# ### **_Time Series Analysis (New Enrollments)_**

# %%
# Time Series Analysis (New Enrollments)
CHIP_Data_New_Enrollments = sns.lineplot(x="Month", y="New Enrollment", data=CHIP_Data)

# %% [markdown]
# ### **_Time Series Analysis (Renewals)_**

# %%
# Time Series Analysis (Renewals)
CHIP_Data_Renewals = sns.lineplot(x="Month", y="Renewals", data=CHIP_Data)

# %% [markdown]
# ### **_Time Series Analysis (Disenrollments)_**

# %%
# Time Series Analysis (Renewals)
CHIP_Data_Disenrollment = sns.lineplot(x="Month", y="Disenrollment", data=CHIP_Data)

# %% [markdown]
# ___

# %% [markdown]
# ## **_More Charts:  Multiple Line Plots_**

# %%
# Make a Copy of the Original Data
Transformed_CHIP_Data = CHIP_Data.copy()

# %%
Transformed_CHIP_Data.head()
# Out:
#        Month  CHIP Caseload  New Enrollment  Renewals  Disenrollment
# 0 2018-10-01         384336           27548      9511          33315
# 1 2018-09-01         390250           28724     12544          30437
# 2 2018-08-01         392085           30811      8822          31635
# 3 2018-07-01         393065           26214      9329          30646
# 4 2018-06-01         397606           28397     14196          39027

# %%
# Transform the CHIP Data
Transformed_CHIP_Data_I = pd.melt(Transformed_CHIP_Data, id_vars = ['Month'], value_vars = ['CHIP Caseload', 'New Enrollment', 'Renewals', 'Disenrollment'], var_name = "CHIP_Type", value_name = 'Number_Of_Records')

# %%
Transformed_CHIP_Data_I.head()
# Out:
#        Month      CHIP_Type  Number_Of_Records
# 0 2018-10-01  CHIP Caseload             384336
# 1 2018-09-01  CHIP Caseload             390250
# 2 2018-08-01  CHIP Caseload             392085
# 3 2018-07-01  CHIP Caseload             393065
# 4 2018-06-01  CHIP Caseload             397606

# %%
CHIP_Type_Line_Plot = sns.lineplot(x = "Month", y = "Number_Of_Records", hue = "CHIP_Type", data = Transformed_CHIP_Data_I)

# %%
Subset_List = ['CHIP Caseload']

Transformed_CHIP_Data_II = Transformed_CHIP_Data_I.query("CHIP_Type not in @Subset_List")

CHIP_Type_Line_Plot_I = sns.lineplot(x = "Month", y = "Number_Of_Records", hue = "CHIP_Type", data = Transformed_CHIP_Data_II)

# %% [markdown]
# ___

# %% [markdown]
# ## **_Export the Data to Excel_**

# %%
# Export the Data Using Pandas
CHIP_Data.to_excel("Python_Tutorial_2019.xlsx", sheet_name = "Python_2019")

# %% [markdown]
# # **_Congratuations on Completing the Python Tutorial!_**
